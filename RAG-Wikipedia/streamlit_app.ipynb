# %%
import os
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/My Drive/OfficeWorks/RAG/

# %%
# !mkdir -p model
# !mkdir -p vectorstore

# %%
# !pip install -r requirements.txt

# %%
os.environ['HF_AUTH_TOKEN'] = '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'

# %%
# !streamlit run app.py &>/dev/null&

# %%
from pyngrok import ngrok

# Set ngrok auth token and start an ngrok tunnel
ngrok.set_auth_token("2i8gjHToj3EbhxebysxdhtTKtPx_3VW2PWXLpdjroKyiHFK5U")
public_url = ngrok.connect(8501, "http")
print("Public URL:", public_url)
